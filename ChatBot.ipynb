# %%
GEMINI_API_KEY='AIzaSyDBRFbn9GOrjwYqJcdS4gcGRXVY6zsslwM'

# %% [raw]
# !pip install google-genai

# %%
from google import genai

# %%
client= genai.Client(api_key=GEMINI_API_KEY)

# %%
print(f"lets find the avalible models")
for m in client.models.list():
    if m.supported_actions and 'generateContent' in m.supported_actions:
        print(f'-{m.name}')
# Out:
# lets find the avalible models
# -models/gemini-2.5-flash
# -models/gemini-2.5-pro
# -models/gemini-2.0-flash
# -models/gemini-2.0-flash-001
# -models/gemini-2.0-flash-lite-001
# -models/gemini-2.0-flash-lite
# -models/gemini-2.5-flash-preview-tts
# -models/gemini-2.5-pro-preview-tts
# -models/gemma-4-26b-a4b-it
# -models/gemma-4-31b-it
# -models/gemini-flash-latest
# -models/gemini-flash-lite-latest
# -models/gemini-pro-latest
# -models/gemini-2.5-flash-lite
# -models/gemini-2.5-flash-image
# -models/gemini-3-pro-preview
# -models/gemini-3-flash-preview
# -models/gemini-3.1-pro-preview
# -models/gemini-3.1-pro-preview-customtools
# -models/gemini-3.1-flash-lite-preview
# -models/gemini-3.1-flash-lite
# -models/gemini-3-pro-image-preview
# -models/nano-banana-pro-preview
# -models/gemini-3.1-flash-image-preview
# -models/gemini-3.5-flash
# -models/lyria-3-clip-preview
# -models/lyria-3-pro-preview
# -models/gemini-3.1-flash-tts-preview
# -models/gemini-robotics-er-1.5-preview
# -models/gemini-robotics-er-1.6-preview
# -models/gemini-2.5-computer-use-preview-10-2025
# -models/antigravity-preview-05-2026
# -models/deep-research-max-preview-04-2026
# -models/deep-research-preview-04-2026
# -models/deep-research-pro-preview-12-2025

# %%
from google.genai import types

# %%
config=types.GenerateContentConfig(
    temperature=0.8)

# %%
prompt=input('Your Prompt')
print(f'Asking: {prompt}')
# Out:
# Asking:

# %%
response=client.models.generate_content(
    model='gemini-3.5-flash',
    contents=prompt,
    config=config)

# %%
print(f'Output: ')
print(response.text)
# Out:
# Output:
# The standard and most popular way to connect Python to a PostgreSQL database is using the **`psycopg2`** library (or the newer **`psycopg`** version 3).
#
# Here is a step-by-step guide to connecting to PostgreSQL using both the traditional method (`psycopg2`) and the modern modern method (`psycopg` v3).
#
# ---
#
# ### Method 1: Using `psycopg2` (Most Common)
#
# #### 1. Install the library
# Open your terminal and install the binary version of `psycopg2` (which doesn't require local C compilers):
# ```bash
# pip install psycopg2-binary
# ```
#
# #### 2. Python Code
# Here is a secure template using Python's `with` statement, which automatically closes the connection and cursor when done, even if an error occurs.
#
# ```python
# import psycopg2
#
#
# def connect_to_postgres():
#     # Define connection parameters
#     connection_config = {
#         "host": "localhost",  # or your database IP address
#         "database": "your_database_name",
#         "user": "your_username",
#         "password": "your_password",
#         "port": 5432,  # default PostgreSQL port
#     }
#
#     try:
#         # 1. Connect to the database
#         with psycopg2.connect(**connection_config) as conn:
#             # 2. Open a cursor to perform database operations
#             with conn.cursor() as cursor:
#                 # 3. Execute a SQL query
#                 cursor.execute("SELECT version();")
#
#                 # 4. Fetch the results
#                 db_version = cursor.fetchone()
#                 print(f"Success! Connected to: {db_version[0]}")
#
#     except Exception as error:
#         print(f"Error connecting to database: {error}")
#
#
# if __name__ == "__main__":
#     connect_to_postgres()
# ```
#
# ---
#
# ### Method 2: Using `psycopg` (Psycopg 3 - Modern & Recommended)
#
# `psycopg` (v3) is the newer, redesigned successor to `psycopg2`. It is faster, supports Python's `async/await`, and has native support for static typing.
#
# #### 1. Install the library
# ```bash
# pip install "psycopg[binary]"
# ```
#
# #### 2. Python Code
# The syntax is very similar to version 2, but cleaner:
#
# ```python
# import psycopg
#
#
# def connect_modern():
#     conn_string = "host=localhost dbname=your_database_name user=your_username password=your_password port=5432"
#
#     try:
#         # Connect using the connection string
#         with psycopg.connect(conn_string) as conn:
#             with conn.cursor() as cur:
#                 cur.execute("SELECT version();")
#                 print(cur.fetchone()[0])
#     except Exception as e:
#         print(f"Error: {e}")
#
#
# if __name__ == "__main__":
#     connect_modern()
# ```
#
# ---
#
# ### Best Practices
#
# #### 1. Use Environment Variables (Security)
# Never hardcode your database passwords in your Python files. Use environment variables.
#
# Install `python-dotenv`:
# ```bash
# pip install python-dotenv
# ```
# Create a `.env` file in your project folder:
# ```env
# DB_HOST=localhost
# DB_NAME=mydb
# DB_USER=postgres
# DB_PASSWORD=mysecretpassword
# DB_PORT=5432
# ```
# Read them in Python:
# ```python
# import os
# from dotenv import load_dotenv
# import psycopg2
#
# load_dotenv()  # Loads variables from .env file
#
# conn = psycopg2.connect(
#     host=os.getenv("DB_HOST"),
#     database=os.getenv("DB_NAME"),
#     user=os.getenv("DB_USER"),
#     password=os.getenv("DB_PASSWORD"),
#     port=os.getenv("DB_PORT"),
# )
# ```
#
# #### 2. Reading Data into Pandas (For Data Scientists)
# If you are doing data analysis, you can easily load PostgreSQL data into a Pandas DataFrame using `sqlalchemy`:
#
# ```bash
# pip install pandas sqlalchemy psycopg2
# ```
#
# ```python
# import pandas as pd
# from sqlalchemy import create_engine
#
# # Format: postgresql://username:password@host:port/database
# engine = create_engine("postgresql://user:pass@localhost:5432/mydb")
#
# df = pd.read_sql("SELECT * FROM my_table", engine)
# print(df.head())
# ```

# %%
config=types.GenerateContentConfig(
    temperature=0.3,
    system_instruction="You are a grumpy pirates. Always speak like a pirate"
)

# %%
chat=client.chats.create(
    model='gemini-3.5-flash',
    config=config)

# %%
print(f'Pirate Chatbot is going to start! Type quit to exit the  conversation')
while True:
    user_input=input("You: ")
    if user_imput=='quit':
        break
    print('Pirates: ',end=" ")
    response=chat.send_message_stream(user_input)
    for chunk in response:
        print(chunk.text, end=" ",flush=True)

    print('\n')
# Out:
# Pirate Chatbot is going to start! Type quit to exit the  conversation
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 while True:
#       3     user_input=input("You: ")
# ----> 4     if user_imput=='quit':
#       5         break
#       6     print('Pirates: ',end=" ")
#
# NameError: name 'user_imput' is not defined
